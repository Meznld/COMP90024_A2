# %%
import couchdb
import os
import matplotlib.pyplot as plt
import geopandas as gpd


fp = '/Users/belkok/Downloads/Output__spatialise-dataset_Apr-28_10_41/shp/sa2_p32_tenure_landlord_type_by_dwelling_struct_census_2016-.shp'

house_type = gpd.read_file(fp)

house_type.to_crs(epsg=4283).plot()
# Out:
# <AxesSubplot:>

# %%
house_type.explore()

# %%
fp1 = '/Users/belkok/Documents/GitHub/COMP90024/COMP90024_A2/data/spatialise-PI/shp/sa2_p02_selected_medians_and_averages_census_2016-.shp'
income = gpd.read_file(fp)
# income = income[(income.median_mo0 > 2000)]
income['median_mo0']
income.to_crs(epsg=4283).plot(cmap='OrRd', scheme='quantiles')
# Out:
# <AxesSubplot:>

# %%
income['median_mo0']
# Out:
# 0      1752
# 1      2080
# 2      1733
# 3      2167
# 4      2171
#        ...
# 304    2200
# 305    2000
# 306    1668
# 307    1517
# 308    1600
# Name: median_mo0, Length: 309, dtype: int64
